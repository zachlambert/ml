# %%
import sys
sys.path.append("../")
from ml import regression
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-43acb4bc1d8b> in <module>
#       1 import sys
#       2 sys.path.append("../")
# ----> 3 from ml import regression
#
# ~/code/projects/machine_learning/ml_library/ml/regression/__init__.py in <module>
#       4 from ._manager import Manager
#       5 from ._model_linear import RegressionModelLinear
# ----> 6 from ._plot import (
#       7     plot_regression_data_one_feature,
#       8     plot_regression_data_two_features,
#
# ~/code/projects/machine_learning/ml_library/ml/regression/_plot.py in <module>
#       1 import matplotlib.pyplot as plt
# ----> 2 from ml.plot import plot_contours
#       3
#       4
#       5 def plot_data_one_feature(ax, manager, name):
#
# ModuleNotFoundError: No module named 'ml.plot'

# %%
d = data.DummyData()
d.generate_X_gaussian(2, 1000)
weights, snr = d.generate_y(common.make_transform_X_linear())

r = regression.RegressionManager(2)
r.load_data(d.X, d.y)

print(weights)
print(r.feature_names)
# Out:
# [[ 1.40152752]
#  [-0.21245433]
#  [-2.86071058]]
# ['feature 1', 'feature 2']

# %%
regression.plot_regression_data_one_feature(None, r, "feature 1")

# %%
regression.plot_regression_data_two_features(
    None, r, "feature 1", "feature 2")

# %%
r.add_model(regression.RegressionModelLinear(var_e=0.1))
r.add_model(regression.RegressionModelLinear(var_e=0.1))
r.add_model(regression.RegressionModelLinear(var_e=0.1))

r.fit()
print(r.models[0].w_mean)

regression.plot_regression_result_one_feature(None, r, "feature 1")
regression.plot_regression_result_one_feature(None, r, "feature 2")
# Out:
# [[ 1.38696035]
#  [-0.16507118]
#  [-2.78623481]]
